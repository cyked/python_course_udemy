# %%
import os
os.listdir()
# Out:
# ['Untitled.ipynb',
#  'supermarkets.json',
#  'supermarkets.csv',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.xlsx',
#  '.ipynb_checkpoints',
#  'supermarkets-commas.txt']

# %%
import pandas

# %%
df1=pandas.read_csv("supermarkets.csv")
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df2=pandas.read_json("supermarkets.json")
df2
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df3=pandas.read_excel("supermarkets.xlsx", sheet_name=0)
df3
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df4=pandas.read_csv("supermarkets-commas.txt")
df4
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5=pandas.read_csv("supermarkets-semi-colons.txt")
df5
# Out:
#         ID;Address;City;State;Country;Name;Employees
# 0  1;3666 21st St;San Francisco;CA 94114;USA;Made...
# 1  2;735 Dolores St;San Francisco;CA 94119;USA;Br...
# 2  3;332 Hill St;San Francisco;California 94114;U...
# 3  4;3995 23rd St;San Francisco;CA 94114;USA;Ben'...
# 4  5;1056 Sanchez St;San Francisco;California;USA...
# 5  6;551 Alvarado St;San Francisco;CA 94114;USA;R...

# %%
df6=pandas.read_csv("supermarkets-semi-colons.txt",sep=";")
df6
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df7=pandas.read_csv("data.txt", header=None)
df7
# Out:
#    0                1              2                 3    4            5   6
# 0  1     3666 21st St  San Francisco          CA 94114  USA      Madeira   8
# 1  2   735 Dolores St  San Francisco          CA 94119  USA  Bready Shop  15
# 2  3      332 Hill St  San Francisco  California 94114  USA  Super River  25
# 3  4     3995 23rd St  San Francisco          CA 94114  USA   Ben's Shop  10
# 4  5  1056 Sanchez St  San Francisco        California  USA      Sanchez  12
# 5  6  551 Alvarado St  San Francisco          CA 94114  USA   Richvalley  20

# %%
df7.columns = ["ID","Address","City","Country/Zip","Country","Name","Employees"]
df7
# Out:
#    ID          Address           City       Country/Zip Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df7.set_index("ID")
df7
# Out:
#    ID          Address           City       Country/Zip Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df8=df7.set_index("ID")
df8
# Out:
#             Address           City       Country/Zip Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df7.set_index("ID",inplace=True)
df7
# Out:
#             Address           City       Country/Zip Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df8.set_index("Address",inplace=True)
df8
# Out:
#                           City       Country/Zip Country         Name  \
# Address
# 3666 21st St     San Francisco          CA 94114     USA      Madeira
# 735 Dolores St   San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St      San Francisco  California 94114     USA  Super River
# 3995 23rd St     San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St  San Francisco        California     USA      Sanchez
# 551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
df8.set_index("Name",inplace=True,drop=False)
df8
# Out:
#                       City       Country/Zip Country         Name  Employees
# Name
#  Madeira     San Francisco          CA 94114     USA      Madeira          8
# Bready Shop  San Francisco          CA 94119     USA  Bready Shop         15
# Super River  San Francisco  California 94114     USA  Super River         25
# Ben's Shop   San Francisco          CA 94114     USA   Ben's Shop         10
# Sanchez      San Francisco        California     USA      Sanchez         12
# Richvalley   San Francisco          CA 94114     USA   Richvalley         20

# %%
df7
# Out:
#             Address           City       Country/Zip Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df7["Continent"]=df7.shape[0]*["North America"]
df7
# Out:
#             Address           City       Country/Zip Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees      Continent
# ID
# 1           8  North America
# 2          15  North America
# 3          25  North America
# 4          10  North America
# 5          12  North America
# 6          20  North America

# %%
df7["Continent"] = df7["Country"] + "," + ["North America"]
df7
# Out:
#             Address           City       Country/Zip Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees          Continent
# ID
# 1           8  USA,North America
# 2          15  USA,North America
# 3          25  USA,North America
# 4          10  USA,North America
# 5          12  USA,North America
# 6          20  USA,North America

# %%
df7_t = df7.T
df7_t
# Out:
# ID                           1                  2                  3  \
# Address           3666 21st St     735 Dolores St        332 Hill St
# City             San Francisco      San Francisco      San Francisco
# Country/Zip           CA 94114           CA 94119   California 94114
# Country                    USA                USA                USA
# Name                   Madeira        Bready Shop        Super River
# Employees                    8                 15                 25
# Continent    USA,North America  USA,North America  USA,North America
#
# ID                           4                  5                  6
# Address           3995 23rd St    1056 Sanchez St    551 Alvarado St
# City             San Francisco      San Francisco      San Francisco
# Country/Zip           CA 94114         California           CA 94114
# Country                    USA                USA                USA
# Name                Ben's Shop            Sanchez         Richvalley
# ...

# %%
df9 = df7_t

# %%
df9["My ID"] = ["My Address","My City","My State","My Country","My Shop",10,"My Continent"]
df9
# Out:
# ID                           1                  2                  3  \
# Address           3666 21st St     735 Dolores St        332 Hill St
# City             San Francisco      San Francisco      San Francisco
# Country/Zip           CA 94114           CA 94119   California 94114
# Country                    USA                USA                USA
# Name                   Madeira        Bready Shop        Super River
# Employees                    8                 15                 25
# Continent    USA,North America  USA,North America  USA,North America
#
# ID                           4                  5                  6  \
# Address           3995 23rd St    1056 Sanchez St    551 Alvarado St
# City             San Francisco      San Francisco      San Francisco
# Country/Zip           CA 94114         California           CA 94114
# Country                    USA                USA                USA
# ...

# %%
df10=df9.T
df10
# Out:
#                Address           City       Country/Zip     Country  \
# ID
# 1         3666 21st St  San Francisco          CA 94114         USA
# 2       735 Dolores St  San Francisco          CA 94119         USA
# 3          332 Hill St  San Francisco  California 94114         USA
# 4         3995 23rd St  San Francisco          CA 94114         USA
# 5      1056 Sanchez St  San Francisco        California         USA
# 6      551 Alvarado St  San Francisco          CA 94114         USA
# My ID       My Address        My City          My State  My Country
#
#               Name Employees          Continent
# ID
# 1          Madeira         8  USA,North America
# 2      Bready Shop        15  USA,North America
# 3      Super River        25  USA,North America
# 4       Ben's Shop        10  USA,North America
# 5          Sanchez        12  USA,North America
# 6       Richvalley        20  USA,North America
# My ID      My Shop        10       My Continent

# %%
import geopy
dir(geopy)
# Out:
# ['AlgoliaPlaces',
#  'ArcGIS',
#  'AzureMaps',
#  'BANFrance',
#  'Baidu',
#  'BaiduV3',
#  'Bing',
#  'DataBC',
#  'GeoNames',
#  'GeocodeEarth',
#  'Geocodio',
#  'Geolake',
#  'GoogleV3',
#  'Here',
#  'HereV7',
#  'IGNFrance',
#  'LiveAddress',
#  'Location',
#  'MapBox',
#  'MapQuest',
#  'MapTiler',
#  'Nominatim',
#  'OpenCage',
#  'OpenMapQuest',
#  'Pelias',
#  'Photon',
#  'PickPoint',
#  'Point',
#  'Timezone',
#  'TomTom',
#  'What3Words',
#  'What3WordsV3',
#  'Yandex',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '__version_info__',
#  'adapters',
#  'compat',
#  'exc',
#  'format',
#  'geocoders',
#  'get_geocoder_for_service',
#  'get_version',
#  'location',
#  'point',
#  'timezone',
#  'units',
#  'util']

# %%
from geopy.geocoders import ArcGIS

# %%
nom=ArcGIS()

# %%
nom.geocode("1260 East University Dr, Tempe, AZ, 85281")
# Out:
# Location(1260 E University Dr, Tempe, Arizona, 85281, (33.4229969947706, -111.91870903219967, 0.0))

# %%
 n = nom.geocode("1260 East University Dr, Tempe, AZ, 85281")
print(n)
# Out:
# 1260 E University Dr, Tempe, Arizona, 85281

# %%
n.latitude
# Out:
# 33.4229969947706

# %%
n.longitude
# Out:
# -111.91870903219967

# %%
type(n)
# Out:
# geopy.location.Location

# %%
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df = pandas.read_csv("supermarkets.csv")
df["Address"] = df["Address"] + ", " + df["City"] + ", " + df["State"] + ", " + df["Country"]
df
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country         Name  Employees
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20

# %%
df["Coordooinates"] = df["Address"].apply(nom.geocode)
df
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                        Coordooinates
# ...
